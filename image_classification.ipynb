# %% [markdown]
# 1. Load and Prepare Data:

# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values from 0-255 to 0-1
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# 2. Build a Sequential Model:

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)), # Flattens 2D images to 1D
  tf.keras.layers.Dense(128, activation='relu'), # Dense layer with ReLU activation
  tf.keras.layers.Dropout(0.2), # Dropout for regularization
  tf.keras.layers.Dense(10) # Output layer with 10 units for 10 classes
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# 3. Define Loss and Optimizer:

# %%
# Use SparseCategoricalCrossentropy for integer labels
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# 4. Train the Model:

# %%
model.fit(x_train, y_train, epochs=5) # Train for 5 epochs
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8598 - loss: 0.4848
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9551 - loss: 0.1510
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9661 - loss: 0.1109
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9727 - loss: 0.0891
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9767 - loss: 0.0752

# %% [markdown]
# 5. Evaluate the Model:

# %%
model.evaluate(x_test, y_test, verbose=2) # Evaluate on test data
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.9742 - loss: 0.0832
# [0.08320349454879761, 0.9742000102996826]
